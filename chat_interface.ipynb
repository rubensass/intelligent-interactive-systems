# %%
from search_assistant.assistant import Assistant

answer = ""
assistant = Assistant()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from search_assistant.assistant import Assistant
#       3 answer = ""
#       4 assistant = Assistant()
#
# File c:\Users\ruben\Desktop\TECHNION\cours_Technion_year_5\NEVONOT\PROJECT\intelligent-interactive-systems\search_assistant\assistant.py:4
#       1 from pydantic import BaseModel
#       2 from typing import Any
# ----> 4 from search_assistant.RAG import RAG
#       7 def process_llm_response(llm_response):
#       8     answer = llm_response["result"]
#
# File c:\Users\ruben\Desktop\TECHNION\cours_Technion_year_5\NEVONOT\PROJECT\intelligent-interactive-systems\search_assistant\RAG.py:18
#      13 from langchain.document_loaders import DirectoryLoader
#      15 load_dotenv("local.env")
# ---> 18 class RAG(BaseModel):
#      19     openai_api_key: str = os.getenv("OPENAI_API_KEY")
#      20     documents_path: str = "../all_books"
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\main.py:197, in pydantic.main.ModelMetaclass.__new__()
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\fields.py:504, in pydantic.fields.ModelField.infer()
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\fields.py:434, in pydantic.fields.ModelField.__init__()
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\fields.py:544, in pydantic.fields.ModelField.prepare()
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\fields.py:568, in pydantic.fields.ModelField._set_default_and_type()
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\fields.py:437, in pydantic.fields.ModelField.get_default()
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\utils.py:693, in pydantic.utils.smart_deepcopy()
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
#     [... skipping similar frames: _deepcopy_dict at line 231 (4 times), deepcopy at line 146 (4 times), _reconstruct at line 271 (3 times), deepcopy at line 172 (3 times)]
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\ruben\AppData\Local\Programs\Python\Python311\Lib\copy.py:161, in deepcopy(x, memo, _nil)
#     159 reductor = getattr(x, "__reduce_ex__", None)
#     160 if reductor is not None:
# --> 161     rv = reductor(4)
#     162 else:
#     163     reductor = getattr(x, "__reduce__", None)
#
# TypeError: cannot pickle '_thread.RLock' object

# %%
# TO STOP THE CONVERSATION TELL 'stop' TO THE ASSISTANT #

print("Hello, welcome to our store, how may I help you?")

while answer != "Goodbye, have a nice day!":
    query = input()
    print(query)
    print("/n")
    answer = assistant.ask_to_assistant(query)
    print(answer)
    print("/n/n")
